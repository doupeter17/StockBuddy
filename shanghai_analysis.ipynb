# %% [markdown]
# # Importing Data
# This is a project about Data Analysis for the objective stock indicators from ShangHai and Vietnam, the data is collected from the range 2020 to 2024. The source for ShangHai stock dataset is S&P Global, and VCI(VietCap Stock)

# %%
pip install shap
# Out:
# Collecting shap
#   Downloading shap-0.46.0-cp312-cp312-win_amd64.whl.metadata (25 kB)
# Requirement already satisfied: numpy in c:\users\ntuan\anaconda3\lib\site-packages (from shap) (1.26.4)
# Requirement already satisfied: scipy in c:\users\ntuan\anaconda3\lib\site-packages (from shap) (1.13.1)
# Requirement already satisfied: scikit-learn in c:\users\ntuan\anaconda3\lib\site-packages (from shap) (1.5.1)
# Requirement already satisfied: pandas in c:\users\ntuan\anaconda3\lib\site-packages (from shap) (2.2.2)
# Requirement already satisfied: tqdm>=4.27.0 in c:\users\ntuan\anaconda3\lib\site-packages (from shap) (4.66.5)
# Requirement already satisfied: packaging>20.9 in c:\users\ntuan\anaconda3\lib\site-packages (from shap) (24.1)
# Collecting slicer==0.0.8 (from shap)
#   Downloading slicer-0.0.8-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: numba in c:\users\ntuan\anaconda3\lib\site-packages (from shap) (0.60.0)
# Requirement already satisfied: cloudpickle in c:\users\ntuan\anaconda3\lib\site-packages (from shap) (3.0.0)
# Requirement already satisfied: colorama in c:\users\ntuan\anaconda3\lib\site-packages (from tqdm>=4.27.0->shap) (0.4.6)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in c:\users\ntuan\anaconda3\lib\site-packages (from numba->shap) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ntuan\anaconda3\lib\site-packages (from pandas->shap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ntuan\anaconda3\lib\site-packages (from pandas->shap) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ntuan\anaconda3\lib\site-packages (from pandas->shap) (2023.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\ntuan\anaconda3\lib\site-packages (from scikit-learn->shap) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\ntuan\anaconda3\lib\site-packages (from scikit-learn->shap) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\ntuan\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->shap) (1.16.0)
# Downloading shap-0.46.0-cp312-cp312-win_amd64.whl (456 kB)
# Downloading slicer-0.0.8-py3-none-any.whl (15 kB)
# Installing collected packages: slicer, shap
# Successfully installed shap-0.46.0 slicer-0.0.8
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Load the dataset

# %%
import shap
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
from linearmodels.panel import PanelOLS, RandomEffects
from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error, mean_absolute_percentage_error

# %% [markdown]
# The raw dataset is provided in folder, and load into DataFrame

# %%
vn_df = pd.read_csv("vietnam_data.csv")
vn_df
# Out:
#       Comp_data  Year  Quarter         EPS         BVPS       ROA       ROE  \
# 0           AAV  2024        1  -48.079754  10726.64399 -0.018067 -0.022292
# 1           AAV  2024        2  -27.627976  10699.01602 -0.015186 -0.018721
# 2           AAV  2024        3  -27.095742  10671.92028 -0.012993 -0.015996
# 3           AAV  2023        1  -48.477520  10971.74966 -0.001734 -0.002448
# 4           AAV  2023        2  -67.213499  10904.53616 -0.011205 -0.015320
# ...         ...   ...      ...         ...          ...       ...       ...
# 17883       XMP  2023        4  245.606801  11476.31876  0.011925  0.028992
# 17884       XMP  2022        1  453.834519  11481.76614  0.033454  0.090928
# 17885       XMP  2022        2  225.706812  10679.54133  0.024045  0.064674
# 17886       XMP  2022        3  224.676527  10904.21786  0.037683  0.100155
# 17887       XMP  2022        4  468.729431  11231.07091  0.047368  0.123528
#
#         P/E Ratio       DAR        MB        DY       DIV    Market Cap  \
# 0      -25.300774  0.146169  0.568677  0.000000  0.000000  4.210000e+11
# 1      -28.782145  0.146289  0.542106  0.000000  0.000000  4.000000e+11
# 2      -41.990328  0.147597  0.674668  0.000000  0.000000  4.970000e+11
# 3     -221.925697  0.241432  0.546859  0.000000  0.000000  4.140000e+11
# 4      -27.290519  0.149924  0.421843  0.000000  0.000000  3.170000e+11
# ...           ...       ...       ...       ...       ...           ...
# 17883   58.936098  0.574130  1.690438  0.010309  0.191959  2.910000e+11
# 17884   16.670194  0.611227  1.463190  0.053571  0.798750  2.520000e+11
# 17885   24.167644  0.632687  1.610556  0.052326  0.849244  2.580000e+11
# 17886   16.303713  0.621295  1.650737  0.050000  0.754500  2.700000e+11
# 17887   12.365405  0.602622  1.513658  0.052941  0.960882  2.550000e+11
#
#        Total Assets  Stock Price
# 0      9.090000e+11         3.70
# 1      9.070000e+11         5.50
# 2      9.070000e+11         6.40
# 3      1.060000e+12         3.90
# 4      9.280000e+11         5.40
# ...             ...          ...
# 17883  4.042190e+11        18.62
# 17884  4.430010e+11        14.91
# 17885  4.361210e+11        16.23
# 17886  4.319010e+11        15.09
# 17887  4.238740e+11        18.15
#
# [17888 rows x 15 columns]

# %%
sh_df = pd.read_csv("shanghai.csv")
sh_df
# Out:
#        Comp_code        Time Total Assets  Total Debt   EPS   BVPS   ROA  \
# 0         600000   9/30/2024      9416535  8685534.00  0.23  24.62  0.00
# 1         600000   6/30/2024      9253778  8500022.00  0.36  21.65  0.01
# 2         600000   3/31/2024      9053468  8302126.00  0.57  25.31  0.00
# 3         600000  12/31/2023      9007247  8274363.00  0.15  20.94  0.00
# 4         600000   9/30/2023      8808320  8084504.00  0.12  24.38  0.00
# ...          ...         ...          ...         ...   ...    ...   ...
# 16597     603920   3/31/2021         5025     2175.00  0.05   5.35  0.07
# 16598     603920  12/31/2020         3803     1103.00  0.17   5.07  0.08
# 16599     603920   9/30/2020         3821     1217.00  0.14   4.89  0.07
# 16600     603920   6/30/2020         3751     1215.00  0.17   4.76  0.03
# 16601     603920   3/31/2020         3495      848.54  0.10   4.97  0.09
#
#         ROE    DY  Price   DIV  Market Cap
# 0      0.05  0.00   9.87  0.00    297338.0
# 1      0.10  0.00   7.94  0.00    241568.0
# 2      0.05  0.00   6.88  0.00    209281.0
# 3      0.03  0.05   6.38  0.32    194311.0
# 4      0.04  0.00   6.85  0.00    208400.0
# ...     ...   ...    ...   ...         ...
# 16597  0.13    Na  11.04    Na      6843.0
# 16598  0.11  0.03  17.56  0.46     10712.0
# 16599  0.14    Na  16.79    Na     10074.0
# 16600  0.08    Na  15.93    Na     10151.0
# 16601  0.18    Na  12.29    Na      7452.0
#
# [16602 rows x 12 columns]

# %% [markdown]
# ## Pre-processing Data

# %% [markdown]
# ### ShangHai Dataset

# %% [markdown]
# Replace Na to NaN in the dataset

# %%
sh_df.replace("Na",np.nan,inplace= True)
sh_df
# Out:
#        Comp_code        Time Total Assets  Total Debt   EPS   BVPS   ROA  \
# 0         600000   9/30/2024      9416535  8685534.00  0.23  24.62  0.00
# 1         600000   6/30/2024      9253778  8500022.00  0.36  21.65  0.01
# 2         600000   3/31/2024      9053468  8302126.00  0.57  25.31  0.00
# 3         600000  12/31/2023      9007247  8274363.00  0.15  20.94  0.00
# 4         600000   9/30/2023      8808320  8084504.00  0.12  24.38  0.00
# ...          ...         ...          ...         ...   ...    ...   ...
# 16597     603920   3/31/2021         5025     2175.00  0.05   5.35  0.07
# 16598     603920  12/31/2020         3803     1103.00  0.17   5.07  0.08
# 16599     603920   9/30/2020         3821     1217.00  0.14   4.89  0.07
# 16600     603920   6/30/2020         3751     1215.00  0.17   4.76  0.03
# 16601     603920   3/31/2020         3495      848.54  0.10   4.97  0.09
#
#         ROE    DY  Price   DIV  Market Cap
# 0      0.05  0.00   9.87  0.00    297338.0
# 1      0.10  0.00   7.94  0.00    241568.0
# 2      0.05  0.00   6.88  0.00    209281.0
# 3      0.03  0.05   6.38  0.32    194311.0
# 4      0.04  0.00   6.85  0.00    208400.0
# ...     ...   ...    ...   ...         ...
# 16597  0.13   NaN  11.04   NaN      6843.0
# 16598  0.11  0.03  17.56  0.46     10712.0
# 16599  0.14   NaN  16.79   NaN     10074.0
# 16600  0.08   NaN  15.93   NaN     10151.0
# 16601  0.18   NaN  12.29   NaN      7452.0
#
# [16602 rows x 12 columns]

# %% [markdown]
# #### Observe the dataset to measure the null value of each columns.

# %%
missing_data = sh_df.isnull()
for column in missing_data.columns.tolist():
    print(column)
    print(f"Missing value: {missing_data[column].value_counts()}")
# Out:
# Comp_code
# Missing value: Comp_code
# False    16602
# Name: count, dtype: int64
# Time
# Missing value: Time
# False    16602
# Name: count, dtype: int64
# Total Assets
# Missing value: Total Assets
# False    16442
# True       160
# Name: count, dtype: int64
# Total Debt
# Missing value: Total Debt
# False    16442
# True       160
# Name: count, dtype: int64
# EPS
# Missing value: EPS
# False    16577
# True        25
# Name: count, dtype: int64
# BVPS
# Missing value: BVPS
# False    16456
# True       146
# Name: count, dtype: int64
# ROA
# Missing value: ROA
# False    16153
# True       449
# Name: count, dtype: int64
# ROE
# Missing value: ROE
# False    16145
# True       457
# Name: count, dtype: int64
# DY
# Missing value: DY
# False    11138
# True      5464
# Name: count, dtype: int64
# Price
# Missing value: Price
# False    16602
# Name: count, dtype: int64
# DIV
# Missing value: DIV
# False    11138
# True      5464
# Name: count, dtype: int64
# Market Cap
# Missing value: Market Cap
# False    16583
# True        19
# Name: count, dtype: int64

# %% [markdown]
# #### Replace DY null values with 0

# %%
sh_df["DY"].fillna(0, inplace = True)
sh_df["DIV"].fillna(0, inplace = True)
sh_df
# Out:
# C:\Users\ntuan\AppData\Local\Temp\ipykernel_13756\3079783968.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   sh_df["DY"].fillna(0, inplace = True)
# C:\Users\ntuan\AppData\Local\Temp\ipykernel_13756\3079783968.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   sh_df["DIV"].fillna(0, inplace = True)
#        Comp_code        Time Total Assets  Total Debt   EPS   BVPS   ROA  \
# 0         600000   9/30/2024      9416535  8685534.00  0.23  24.62  0.00
# 1         600000   6/30/2024      9253778  8500022.00  0.36  21.65  0.01
# 2         600000   3/31/2024      9053468  8302126.00  0.57  25.31  0.00
# 3         600000  12/31/2023      9007247  8274363.00  0.15  20.94  0.00
# 4         600000   9/30/2023      8808320  8084504.00  0.12  24.38  0.00
# ...          ...         ...          ...         ...   ...    ...   ...
# 16597     603920   3/31/2021         5025     2175.00  0.05   5.35  0.07
# 16598     603920  12/31/2020         3803     1103.00  0.17   5.07  0.08
# 16599     603920   9/30/2020         3821     1217.00  0.14   4.89  0.07
# 16600     603920   6/30/2020         3751     1215.00  0.17   4.76  0.03
# 16601     603920   3/31/2020         3495      848.54  0.10   4.97  0.09
#
#         ROE    DY  Price   DIV  Market Cap
# 0      0.05  0.00   9.87  0.00    297338.0
# 1      0.10  0.00   7.94  0.00    241568.0
# 2      0.05  0.00   6.88  0.00    209281.0
# 3      0.03  0.05   6.38  0.32    194311.0
# 4      0.04  0.00   6.85  0.00    208400.0
# ...     ...   ...    ...   ...         ...
# 16597  0.13     0  11.04     0      6843.0
# 16598  0.11  0.03  17.56  0.46     10712.0
# 16599  0.14     0  16.79     0     10074.0
# 16600  0.08     0  15.93     0     10151.0
# 16601  0.18     0  12.29     0      7452.0
#
# [16602 rows x 12 columns]

# %% [markdown]
# #### Drop missing value apply for other columns

# %%
sh_df.dropna(axis = 0, inplace = True)
sh_df
# Out:
#        Comp_code        Time Total Assets  Total Debt   EPS   BVPS   ROA  \
# 0         600000   9/30/2024      9416535  8685534.00  0.23  24.62  0.00
# 1         600000   6/30/2024      9253778  8500022.00  0.36  21.65  0.01
# 2         600000   3/31/2024      9053468  8302126.00  0.57  25.31  0.00
# 3         600000  12/31/2023      9007247  8274363.00  0.15  20.94  0.00
# 4         600000   9/30/2023      8808320  8084504.00  0.12  24.38  0.00
# ...          ...         ...          ...         ...   ...    ...   ...
# 16597     603920   3/31/2021         5025     2175.00  0.05   5.35  0.07
# 16598     603920  12/31/2020         3803     1103.00  0.17   5.07  0.08
# 16599     603920   9/30/2020         3821     1217.00  0.14   4.89  0.07
# 16600     603920   6/30/2020         3751     1215.00  0.17   4.76  0.03
# 16601     603920   3/31/2020         3495      848.54  0.10   4.97  0.09
#
#         ROE    DY  Price   DIV  Market Cap
# 0      0.05  0.00   9.87  0.00    297338.0
# 1      0.10  0.00   7.94  0.00    241568.0
# 2      0.05  0.00   6.88  0.00    209281.0
# 3      0.03  0.05   6.38  0.32    194311.0
# 4      0.04  0.00   6.85  0.00    208400.0
# ...     ...   ...    ...   ...         ...
# 16597  0.13     0  11.04     0      6843.0
# 16598  0.11  0.03  17.56  0.46     10712.0
# 16599  0.14     0  16.79     0     10074.0
# 16600  0.08     0  15.93     0     10151.0
# 16601  0.18     0  12.29     0      7452.0
#
# [15900 rows x 12 columns]

# %% [markdown]
# #### Correcting data types

# %%
sh_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15900 entries, 0 to 16601
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Comp_code     15900 non-null  int64
#  1   Time          15900 non-null  object
#  2   Total Assets  15900 non-null  object
#  3   Total Debt    15900 non-null  object
#  4   EPS           15900 non-null  object
#  5   BVPS          15900 non-null  object
#  6   ROA           15900 non-null  object
#  7   ROE           15900 non-null  object
#  8   DY            15900 non-null  object
#  9   Price         15900 non-null  float64
#  10  DIV           15900 non-null  object
#  11  Market Cap    15900 non-null  float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 1.6+ MB

# %%
ignore = ['Time']
sh_df = (sh_df.set_index(ignore, append=True)
        .astype(float)
        .reset_index(ignore)
       )
sh_df["Time"].astype("datetime64[ns]")
sh_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15900 entries, 0 to 16601
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Time          15900 non-null  object
#  1   Comp_code     15900 non-null  float64
#  2   Total Assets  15900 non-null  float64
#  3   Total Debt    15900 non-null  float64
#  4   EPS           15900 non-null  float64
#  5   BVPS          15900 non-null  float64
#  6   ROA           15900 non-null  float64
#  7   ROE           15900 non-null  float64
#  8   DY            15900 non-null  float64
#  9   Price         15900 non-null  float64
#  10  DIV           15900 non-null  float64
#  11  Market Cap    15900 non-null  float64
# dtypes: float64(11), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# #### Split data

# %%
shl_df= sh_df[sh_df["Market Cap"]>70000]
shm_df= sh_df[(sh_df["Market Cap"]<70000) & (sh_df["Market Cap"]>14000)]
shs_df= sh_df[sh_df["Market Cap"]<14000]
shm_df
# Out:
#             Time  Comp_code  Total Assets  Total Debt   EPS  BVPS   ROA   ROE  \
# 19    2024-09-30   600004.0       26982.0     8665.00  0.10  7.64  0.03  0.06
# 20    2024-06-30   600004.0       26955.0     8870.00  0.10  7.54  0.02  0.04
# 21    2024-03-31   600004.0       26597.0     8606.00  0.08  7.52  0.02  0.04
# 22    2023-12-31   600004.0       26190.0     8384.00  0.07  7.43  0.02  0.03
# 23    2023-09-30   600004.0       26765.0     9079.00  0.05  7.38  0.02  0.03
# ...          ...        ...           ...         ...   ...   ...   ...   ...
# 16576 2021-09-30   603919.0        3559.0      659.33  0.11  5.72  0.07  0.10
# 16577 2021-06-30   603919.0        3479.0      635.28  0.14  5.61  0.10  0.16
# 16578 2021-03-31   603919.0        3441.0      547.34  0.23  5.70  0.16  0.26
# 16579 2020-12-31   603919.0        3532.0      753.69  0.34  5.48  0.05  0.06
# 16583 2024-09-30   603920.0        8566.0     2946.00  0.29  8.10  0.06  0.14
#
#          DY  Price   DIV  Market Cap  normalized_total_assets  \
# 19     0.00   9.78  0.00     24756.0                -0.110606
# 20     0.00   9.41  0.00     22436.0                -0.110642
# 21     0.00  10.00  0.00     23857.0                -0.111120
# 22     0.01   9.70  0.08     23147.0                -0.111664
# 23     0.00  11.11  0.00     26507.0                -0.110896
# ...     ...    ...   ...         ...                      ...
# 16576  0.00  33.32  0.00     17485.0                -0.141890
# 16577  0.00  38.95  0.00     20859.0                -0.141996
# 16578  0.00  33.66  0.00     17450.0                -0.142047
# 16579  0.01  37.71  0.24     20539.0                -0.141926
# 16583  0.00  23.15  0.00     16774.0                -0.135202
#
#        normalized_total_debt  normalized_market_cap       DAR       SIZE
# 19                 -0.120044               0.031226  0.321140  10.202925
# 20                 -0.119742              -0.003089  0.329067  10.201924
# 21                 -0.120131               0.017929  0.323570  10.188554
# 22                 -0.120459               0.007427  0.320122  10.173133
# 23                 -0.119433               0.057125  0.339212  10.194850
# ...                      ...                    ...       ...        ...
# 16576              -0.131857              -0.076320  0.185257   8.177235
# 16577              -0.131893              -0.026415  0.182604   8.154500
# 16578              -0.132022              -0.076838  0.159064   8.143517
# 16579              -0.131718              -0.031148  0.213389   8.169620
# 16583              -0.128483              -0.086837  0.343918   9.055556
#
# [3504 rows x 17 columns]

# %% [markdown]
# #### Normalize values

# %%
shs_df["normalized_total_assets"] = (shs_df["Total Assets"]-shs_df["Total Assets"].mean())/shs_df["Total Assets"].std()
# Out:
# C:\Users\ntuan\AppData\Local\Temp\ipykernel_13756\378956679.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shs_df["normalized_total_assets"] = (shs_df["Total Assets"]-shs_df["Total Assets"].mean())/shs_df["Total Assets"].std()

# %%
shs_df["normalized_total_debt"] = (shs_df["Total Debt"]-shs_df["Total Debt"].mean())/shs_df["Total Debt"].std()
# Out:
# C:\Users\ntuan\AppData\Local\Temp\ipykernel_13756\3629549493.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shs_df["normalized_total_debt"] = (shs_df["Total Debt"]-shs_df["Total Debt"].mean())/shs_df["Total Debt"].std()

# %%
shs_df["normalized_market_cap"] = (shs_df["Market Cap"]-shs_df["Market Cap"].mean())/shs_df["Market Cap"].std()
# Out:
# C:\Users\ntuan\AppData\Local\Temp\ipykernel_13756\2607780080.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shs_df["normalized_market_cap"] = (shs_df["Market Cap"]-shs_df["Market Cap"].mean())/shs_df["Market Cap"].std()

# %%
shs_df["DAR"] = shs_df["Total Debt"]/shs_df["Total Assets"]
# Out:
# C:\Users\ntuan\AppData\Local\Temp\ipykernel_13756\2629297266.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shs_df["DAR"] = shs_df["Total Debt"]/shs_df["Total Assets"]

# %%
shs_df["SIZE"] = np.log(shs_df["Total Assets"])
# Out:
# C:\Users\ntuan\AppData\Local\Temp\ipykernel_13756\3718059457.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shs_df["SIZE"] = np.log(shs_df["Total Assets"])

# %%
shm_df
# Out:
#             Time  Comp_code  Total Assets  Total Debt   EPS  BVPS   ROA   ROE  \
# 19    2024-09-30   600004.0       26982.0     8665.00  0.10  7.64  0.03  0.06
# 20    2024-06-30   600004.0       26955.0     8870.00  0.10  7.54  0.02  0.04
# 21    2024-03-31   600004.0       26597.0     8606.00  0.08  7.52  0.02  0.04
# 22    2023-12-31   600004.0       26190.0     8384.00  0.07  7.43  0.02  0.03
# 23    2023-09-30   600004.0       26765.0     9079.00  0.05  7.38  0.02  0.03
# ...          ...        ...           ...         ...   ...   ...   ...   ...
# 16576 2021-09-30   603919.0        3559.0      659.33  0.11  5.72  0.07  0.10
# 16577 2021-06-30   603919.0        3479.0      635.28  0.14  5.61  0.10  0.16
# 16578 2021-03-31   603919.0        3441.0      547.34  0.23  5.70  0.16  0.26
# 16579 2020-12-31   603919.0        3532.0      753.69  0.34  5.48  0.05  0.06
# 16583 2024-09-30   603920.0        8566.0     2946.00  0.29  8.10  0.06  0.14
#
#          DY  Price   DIV  Market Cap  normalized_total_assets  \
# 19     0.00   9.78  0.00     24756.0                -0.265214
# 20     0.00   9.41  0.00     22436.0                -0.265435
# 21     0.00  10.00  0.00     23857.0                -0.268355
# 22     0.01   9.70  0.08     23147.0                -0.271675
# 23     0.00  11.11  0.00     26507.0                -0.266985
# ...     ...    ...   ...         ...                      ...
# 16576  0.00  33.32  0.00     17485.0                -0.456297
# 16577  0.00  38.95  0.00     20859.0                -0.456950
# 16578  0.00  33.66  0.00     17450.0                -0.457260
# 16579  0.01  37.71  0.24     20539.0                -0.456517
# 16583  0.00  23.15  0.00     16774.0                -0.415450
#
#        normalized_total_debt  normalized_market_cap       DAR       SIZE
# 19                 -0.296622              -0.290282  0.321140  10.202925
# 20                 -0.294690              -0.463409  0.329067  10.201924
# 21                 -0.297179              -0.357369  0.323570  10.188554
# 22                 -0.299272              -0.410352  0.320122  10.173133
# 23                 -0.292719              -0.159616  0.339212  10.194850
# ...                      ...                    ...       ...        ...
# 16576              -0.372098              -0.832872  0.185257   8.177235
# 16577              -0.372325              -0.581091  0.182604   8.154500
# 16578              -0.373154              -0.835484  0.159064   8.143517
# 16579              -0.371209              -0.604971  0.213389   8.169620
# 16583              -0.350540              -0.885930  0.343918   9.055556
#
# [3504 rows x 17 columns]

# %% [markdown]
# ## Data Exploring

# %% [markdown]
# #### Data Correlation

# %%
numeric_df = shs_df.select_dtypes(include = ["float64","int64"])
numeric_df.drop("Comp_code",axis=1, inplace = True)
numeric_df.corr()
# Out:
#                          Total Assets  Total Debt       EPS      BVPS  \
# Total Assets                 1.000000    0.987177  0.008716  0.122132
# Total Debt                   0.987177    1.000000 -0.003436  0.084739
# EPS                          0.008716   -0.003436  1.000000  0.366134
# BVPS                         0.122132    0.084739  0.366134  1.000000
# ROA                         -0.024084   -0.031550  0.223009  0.136475
# ROE                         -0.000536   -0.007965  0.065788  0.071835
# DY                           0.061582    0.048978  0.110320  0.125792
# Price                       -0.181114   -0.159930  0.266340  0.539500
# DIV                          0.006923    0.000478  0.138903  0.218338
# Market Cap                   0.348480    0.267848  0.155447  0.142716
# normalized_total_assets      1.000000    0.987177  0.008716  0.122132
# normalized_total_debt        0.987177    1.000000 -0.003436  0.084739
# normalized_market_cap        0.348480    0.267848  0.155447  0.142716
# DAR                          0.392807    0.409740 -0.133106 -0.169832
# SIZE                         0.668215    0.595073  0.040798  0.210440
#
#                               ROA       ROE        DY     Price       DIV  \
# Total Assets            -0.024084 -0.000536  0.061582 -0.181114  0.006923
# Total Debt              -0.031550 -0.007965  0.048978 -0.159930  0.000478
# EPS                      0.223009  0.065788  0.110320  0.266340  0.138903
# BVPS                     0.136475  0.071835  0.125792  0.539500  0.218338
# ROA                      1.000000  0.215332  0.139341  0.160421  0.158938
# ROE                      0.215332  1.000000  0.027452  0.049476  0.028914
# DY                       0.139341  0.027452  1.000000  0.004184  0.760612
# Price                    0.160421  0.049476  0.004184  1.000000  0.149701
# DIV                      0.158938  0.028914  0.760612  0.149701  1.000000
# Market Cap               0.141369  0.045712  0.083246  0.164329  0.085115
# normalized_total_assets -0.024084 -0.000536  0.061582 -0.181114  0.006923
# normalized_total_debt   -0.031550 -0.007965  0.048978 -0.159930  0.000478
# normalized_market_cap    0.141369  0.045712  0.083246  0.164329  0.085115
# DAR                     -0.112462 -0.096619 -0.026557 -0.181104 -0.050323
# SIZE                     0.013548  0.004305  0.091747 -0.238435  0.032858
#
#                          Market Cap  normalized_total_assets  \
# Total Assets               0.348480                 1.000000
# Total Debt                 0.267848                 0.987177
# EPS                        0.155447                 0.008716
# BVPS                       0.142716                 0.122132
# ROA                        0.141369                -0.024084
# ROE                        0.045712                -0.000536
# DY                         0.083246                 0.061582
# Price                      0.164329                -0.181114
# DIV                        0.085115                 0.006923
# Market Cap                 1.000000                 0.348480
# normalized_total_assets    0.348480                 1.000000
# normalized_total_debt      0.267848                 0.987177
# normalized_market_cap      1.000000                 0.348480
# DAR                        0.122615                 0.392807
# SIZE                       0.603023                 0.668215
#
#                          normalized_total_debt  normalized_market_cap  \
# Total Assets                          0.987177               0.348480
# Total Debt                            1.000000               0.267848
# EPS                                  -0.003436               0.155447
# BVPS                                  0.084739               0.142716
# ROA                                  -0.031550               0.141369
# ROE                                  -0.007965               0.045712
# DY                                    0.048978               0.083246
# Price                                -0.159930               0.164329
# DIV                                   0.000478               0.085115
# Market Cap                            0.267848               1.000000
# normalized_total_assets               0.987177               0.348480
# normalized_total_debt                 1.000000               0.267848
# normalized_market_cap                 0.267848               1.000000
# DAR                                   0.409740               0.122615
# SIZE                                  0.595073               0.603023
#
#                               DAR      SIZE
# Total Assets             0.392807  0.668215
# Total Debt               0.409740  0.595073
# EPS                     -0.133106  0.040798
# BVPS                    -0.169832  0.210440
# ROA                     -0.112462  0.013548
# ROE                     -0.096619  0.004305
# DY                      -0.026557  0.091747
# Price                   -0.181104 -0.238435
# DIV                     -0.050323  0.032858
# Market Cap               0.122615  0.603023
# normalized_total_assets  0.392807  0.668215
# normalized_total_debt    0.409740  0.595073
# normalized_market_cap    0.122615  0.603023
# DAR                      1.000000  0.515595
# SIZE                     0.515595  1.000000

# %% [markdown]
# #### Data describe

# %%
numeric_df.describe()
# Out:
#         Total Assets     Total Debt           EPS          BVPS           ROA  \
# count   11372.000000   11372.000000  11372.000000  11372.000000  11372.000000
# mean     9661.177662    6021.996842      0.066690      4.949909      0.019692
# std     20989.338966   17887.960152      0.217153      3.309466      0.056115
# min       102.100000       7.220000     -4.740000     -1.920000     -1.260000
# 25%      2082.750000     640.450000      0.000000      2.830000      0.000000
# 50%      4018.000000    1620.500000      0.050000      4.390000      0.020000
# 75%      8772.000000    4386.250000      0.140000      6.330000      0.040000
# max    393155.000000  361707.000000      5.850000     35.060000      1.750000
#
#                 ROE            DY         Price           DIV    Market Cap  \
# count  11372.000000  11372.000000  11372.000000  11372.000000  11372.000000
# mean       0.015944      0.003080     10.233841      0.028244   5376.947591
# std        1.000245      0.011245      8.136355      0.112329   3298.824964
# min      -91.660000      0.000000      0.660000      0.000000    459.000000
# 25%        0.000000      0.000000      5.087500      0.000000   2743.750000
# 50%        0.050000      0.000000      8.150000      0.000000   4328.500000
# 75%        0.110000      0.000000     12.690000      0.000000   7399.000000
# max       22.540000      0.210000    117.460000      3.790000  13999.000000
#
#        normalized_total_assets  normalized_total_debt  normalized_market_cap  \
# count             1.137200e+04           1.137200e+04           1.137200e+04
# mean             -4.998542e-17          -2.999125e-17           2.999125e-17
# std               1.000000e+00           1.000000e+00           1.000000e+00
# min              -4.554254e-01          -3.362472e-01          -1.490818e+00
# 25%              -3.610608e-01          -3.008474e-01          -7.982229e-01
# 50%              -2.688592e-01          -2.460592e-01          -3.178246e-01
# 75%              -4.236330e-02          -9.144401e-02           6.129614e-01
# max               1.827089e+01           1.988404e+01           2.613674e+00
#
#                 DAR          SIZE
# count  11372.000000  11372.000000
# mean       0.441451      8.414375
# std        0.213131      1.128784
# min        0.006170      4.625953
# 25%        0.279776      7.641444
# 50%        0.436227      8.298539
# 75%        0.588264      9.079320
# max        1.603604     12.881959

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# #### Dataset Preparation

# %%
Y = numeric_df["Price"]
X = numeric_df.drop(["DY","Total Debt","Total Assets", "Market Cap","Price", "normalized_total_assets","normalized_total_debt","normalized_market_cap"],axis = 1)
X
# Out:
#         EPS  BVPS   ROA   ROE   DIV       DAR      SIZE
# 39    -0.04  4.16  0.00  0.06  0.00  0.524483  9.803336
# 41     0.08  4.15 -0.03 -0.02  0.03  0.551533  9.861206
# 42    -0.02  4.07 -0.02 -0.01  0.00  0.543724  9.825039
# 43    -0.01  4.10  0.00  0.05  0.00  0.519860  9.779850
# 44     0.05  4.15 -0.03  0.09  0.00  0.524332  9.800458
# ...     ...   ...   ...   ...   ...       ...       ...
# 16597  0.05  5.35  0.07  0.13  0.00  0.432836  8.522181
# 16598  0.17  5.07  0.08  0.11  0.46  0.290034  8.243546
# 16599  0.14  4.89  0.07  0.14  0.00  0.318503  8.248267
# 16600  0.17  4.76  0.03  0.08  0.00  0.323914  8.229778
# 16601  0.10  4.97  0.09  0.18  0.00  0.242787  8.159089
#
# [11372 rows x 7 columns]

# %%
panel_df = shs_df
panel_df["Time"] = panel_df["Time"].astype("datetime64[ns]")
panel_df = panel_df.set_index(['Comp_code','Time'])
Y_panel = panel_df["Price"]
X_panel = panel_df.drop(["DY","Total Debt","Total Assets", "Market Cap","Price", "normalized_total_assets","normalized_total_debt","normalized_market_cap"],axis = 1)
X_panel = sm.add_constant(X_panel)
X_panel
# Out:
# C:\Users\ntuan\AppData\Local\Temp\ipykernel_13756\246391903.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   panel_df["Time"] = panel_df["Time"].astype("datetime64[ns]")
#                       const   EPS  BVPS   ROA   ROE   DIV       DAR      SIZE
# Comp_code Time
# 600006.0  2024-06-30    1.0 -0.04  4.16  0.00  0.06  0.00  0.524483  9.803336
#           2023-12-31    1.0  0.08  4.15 -0.03 -0.02  0.03  0.551533  9.861206
#           2023-09-30    1.0 -0.02  4.07 -0.02 -0.01  0.00  0.543724  9.825039
#           2023-06-30    1.0 -0.01  4.10  0.00  0.05  0.00  0.519860  9.779850
#           2023-03-31    1.0  0.05  4.15 -0.03  0.09  0.00  0.524332  9.800458
# ...                     ...   ...   ...   ...   ...   ...       ...       ...
# 603920.0  2021-03-31    1.0  0.05  5.35  0.07  0.13  0.00  0.432836  8.522181
#           2020-12-31    1.0  0.17  5.07  0.08  0.11  0.46  0.290034  8.243546
#           2020-09-30    1.0  0.14  4.89  0.07  0.14  0.00  0.318503  8.248267
#           2020-06-30    1.0  0.17  4.76  0.03  0.08  0.00  0.323914  8.229778
#           2020-03-31    1.0  0.10  4.97  0.09  0.18  0.00  0.242787  8.159089
#
# [11372 rows x 8 columns]

# %% [markdown]
# #### OLS model

# %% [markdown]
# Đối với mô hình Least Squared, hay còn gọi là mô hình Linear Regression. Đối với tập train, OLS model trả về R^2 0.722

# %%
X = sm.add_constant(X)
ols_model = sm.OLS(Y,X).fit()
ols_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.453
# Model:                            OLS   Adj. R-squared:                  0.452
# Method:                 Least Squares   F-statistic:                     1343.
# Date:                Fri, 14 Mar 2025   Prob (F-statistic):               0.00
# Time:                        12:40:56   Log-Likelihood:                -36548.
# No. Observations:               11372   AIC:                         7.311e+04
# Df Residuals:                   11364   BIC:                         7.317e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         27.6231      0.443     62.346      0.000      26.755      28.492
# EPS            2.1310      0.285      7.470      0.000       1.572       2.690
# BVPS           1.5623      0.020     78.500      0.000       1.523       1.601
# ROA           12.4841      1.067     11.696      0.000      10.392      14.576
# ROE            0.0117      0.058      0.202      0.840      -0.102       0.126
# DIV            1.0436      0.520      2.006      0.045       0.024       2.063
# DAR            7.2210      0.331     21.822      0.000       6.572       7.870
# SIZE          -3.4142      0.063    -54.618      0.000      -3.537      -3.292
# ==============================================================================
# Omnibus:                     7798.937   Durbin-Watson:                   0.376
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           238996.777
# Skew:                           2.879   Prob(JB):                         0.00
# Kurtosis:                      24.708   Cond. No.                         191.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# #### GLS

# %%
X = sm.add_constant(X)
gls_model = sm.GLS(Y,X).fit()
gls_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             GLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.596
# Model:                            GLS   Adj. R-squared:                  0.595
# Method:                 Least Squares   F-statistic:                     737.5
# Date:                Fri, 14 Mar 2025   Prob (F-statistic):               0.00
# Time:                        12:18:50   Log-Likelihood:                -14719.
# No. Observations:                3504   AIC:                         2.945e+04
# Df Residuals:                    3496   BIC:                         2.950e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        113.9380      2.878     39.591      0.000     108.296     119.581
# EPS            0.7205      0.262      2.754      0.006       0.208       1.234
# BVPS           2.8994      0.060     48.659      0.000       2.783       3.016
# ROA          104.3186      6.370     16.377      0.000      91.829     116.808
# ROE           -0.0339      0.613     -0.055      0.956      -1.235       1.167
# DIV            1.6852      1.562      1.079      0.281      -1.377       4.747
# DAR           31.6950      2.038     15.551      0.000      27.699      35.691
# SIZE         -13.0708      0.333    -39.249      0.000     -13.724     -12.418
# ==============================================================================
# Omnibus:                     2669.435   Durbin-Watson:                   0.409
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            93813.157
# Skew:                           3.282   Prob(JB):                         0.00
# Kurtosis:                      27.484   Cond. No.                         304.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# #### FEM

# %%
fem_model = PanelOLS(Y_panel, X_panel, entity_effects=True)  # entity_effects=True để thêm hiệu ứng cá thể
results = fem_model.fit()
results
# Out:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                  Price   R-squared:                        0.0465
# Estimator:                   PanelOLS   R-squared (Between):              0.0780
# No. Observations:               11372   R-squared (Within):               0.0465
# Date:                Fri, Mar 14 2025   R-squared (Overall):              0.0573
# Time:                        12:42:05   Log-likelihood                -3.002e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      74.840
# Entities:                         622   P-value                           0.0000
# Avg Obs:                       18.283   Distribution:                 F(7,10743)
# Min Obs:                       1.0000
# Max Obs:                       47.000   F-statistic (robust):             74.840
#                                         P-value                           0.0000
# Time periods:                      20   Distribution:                 F(7,10743)
# Avg Obs:                       568.60
# Min Obs:                       2.0000
# Max Obs:                       684.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          0.7134     1.4977     0.4763     0.6339     -2.2224      3.6491
# EPS            1.9246     0.1830     10.515     0.0000      1.5658      2.2833
# BVPS           0.2715     0.0521     5.2076     0.0000      0.1693      0.3737
# ROA            9.4468     0.7084     13.335     0.0000      8.0581      10.835
# ROE           -0.0166     0.0353    -0.4705     0.6380     -0.0857      0.0525
# DIV            2.0844     0.3202     6.5101     0.0000      1.4568      2.7120
# DAR            0.6630     0.5948     1.1148     0.2650     -0.5028      1.8289
# SIZE           0.8926     0.2100     4.2505     0.0000      0.4810      1.3043
# ==============================================================================
#
# F-test for Poolability: 37.239
# P-value: 0.0000
# Distribution: F(621,10743)
#
# Included effects: Entity
# PanelEffectsResults, id: 0x16cd88adfd0

# %% [markdown]
# #### REM

# %%
rem_model = RandomEffects(Y_panel, X_panel)  # entity_effects=True để thêm hiệu ứng cá thể
results = rem_model.fit()
results
# Out:
#                         RandomEffects Estimation Summary
# ================================================================================
# Dep. Variable:                  Price   R-squared:                        0.0970
# Estimator:              RandomEffects   R-squared (Between):              0.4848
# No. Observations:               11372   R-squared (Within):               0.0285
# Date:                Fri, Mar 14 2025   R-squared (Overall):              0.3775
# Time:                        12:42:30   Log-likelihood                -3.053e+04
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      174.37
# Entities:                         622   P-value                           0.0000
# Avg Obs:                       18.283   Distribution:                 F(7,11364)
# Min Obs:                       1.0000
# Max Obs:                       47.000   F-statistic (robust):             149.78
#                                         P-value                           0.0000
# Time periods:                      20   Distribution:                 F(7,11364)
# Avg Obs:                       568.60
# Min Obs:                       2.0000
# Max Obs:                       684.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          17.774     1.1054     16.080     0.0000      15.608      19.941
# EPS            1.9100     0.1855     10.297     0.0000      1.5465      2.2736
# BVPS           0.9437     0.0394     23.924     0.0000      0.8664      1.0210
# ROA            9.4438     0.7170     13.171     0.0000      8.0384      10.849
# ROE           -0.0106     0.0358    -0.2971     0.7664     -0.0808      0.0595
# DIV            2.0779     0.3249     6.3951     0.0000      1.4410      2.7148
# DAR            3.9555     0.5331     7.4206     0.0000      2.9107      5.0004
# SIZE          -1.6947     0.1479    -11.462     0.0000     -1.9846     -1.4049
# ==============================================================================
# RandomEffectsResults, id: 0x16cd88d6f60
